# %% [markdown]
# # Find Source and Import

# %%
import pandas as pd
import requests

url = 'https://api.nytimes.com/svc/books/v3/lists/current/paperback-nonfiction.json?api-key=5lXHw13Pf1zcbEh78ZYgS9feikgdAyEL'
genre = 'https://api.nytimes.com/svc/books/v3/lists/names.json?api-key=5lXHw13Pf1zcbEh78ZYgS9feikgdAyEL'

# %%
r = requests.get(url)
r
# Out:
# <Response [200]>

# %% [markdown]
# After successful connection, convert and view JSON files

# %%
json = r.json()

# %%
json
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2022 The New York Times Company.  All Rights Reserved.',
#  'num_results': 15,
#  'last_modified': '2022-10-26T22:10:35-04:00',
#  'results': {'list_name': 'Paperback Nonfiction',
#   'list_name_encoded': 'paperback-nonfiction',
#   'bestsellers_date': '2022-10-22',
#   'published_date': '2022-11-06',
#   'published_date_description': 'latest',
#   'next_published_date': '',
#   'previous_published_date': '2022-10-30',
#   'display_name': 'Paperback Nonfiction',
#   'normal_list_ends_at': 15,
#   'updated': 'WEEKLY',
#   'books': [{'rank': 1,
#     'rank_last_week': 1,
#     'weeks_on_list': 209,
#     'asterisk': 0,
#     'dagger': 0,
#     'primary_isbn10': '0143127748',
#     'primary_isbn13': '9780143127741',
#     'publisher': 'Penguin',
#     'description': 'How trauma affects the body and mind, and innovative treatments for recovery.',
#     'price': '0.00',
#     'title': 'THE BODY KEEPS THE SCORE',
# ...

# %%
json.keys()
# Out:
# dict_keys(['status', 'copyright', 'num_results', 'last_modified', 'results'])

# %% [markdown]
# Select necessary portions of JSON files, convert to DataFrame and beautify.

# %%
json['results']['books']
# Out:
# [{'rank': 1,
#   'rank_last_week': 1,
#   'weeks_on_list': 209,
#   'asterisk': 0,
#   'dagger': 0,
#   'primary_isbn10': '0143127748',
#   'primary_isbn13': '9780143127741',
#   'publisher': 'Penguin',
#   'description': 'How trauma affects the body and mind, and innovative treatments for recovery.',
#   'price': '0.00',
#   'title': 'THE BODY KEEPS THE SCORE',
#   'author': 'Bessel van der Kolk',
#   'contributor': 'by Bessel van der Kolk',
#   'contributor_note': '',
#   'book_image': 'https://storage.googleapis.com/du-prd/books/images/9780670785933.jpg',
#   'book_image_width': 128,
#   'book_image_height': 193,
#   'amazon_product_url': 'http://www.amazon.com/The-Body-Keeps-Score-Healing/dp/0670785938?tag=NYTBSREV-20',
#   'age_group': '',
#   'book_review_link': 'https://www.nytimes.com/2018/10/18/books/review/how-to-rewire-your-traumatized-brain.html',
#   'first_chapter_link': '',
#   'sunday_review_link': '',
#   'article_chapter_link': '',
# ...

# %%
df = pd.DataFrame(json['results']['books'])

# %%
df.iloc[:,0:13]
# Out:
#     rank  rank_last_week  weeks_on_list  asterisk  dagger primary_isbn10  \
# 0      1               1            209         0       0     0143127748
# 1      2               0              1         0       0     1523523182
# 2      3               3            132         0       0     1571313567
# 3      4               2             46         0       0     0060959479
# 4      5               0              1         0       0     1984899015
# 5      6               5             56         0       0     0316299227
# 6      7               6             15         0       0     0063285320
# 7      8               8            338         0       0     0374533555
# 8      9               4              7         0       0     1335449302
# 9     10              10              3         0       0     0316270180
# 10    11               9              5         0       0     0062964623
# 11    12               0            128         0       0     1501111116
# ...
